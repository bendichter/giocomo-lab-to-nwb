# %%
from pynwb import NWBHDF5IO
from nwbwidgets import nwb2widget
from IPython.display import display
from pathlib import Path
nwbfile = Path.cwd().parents.par/'sbx_nwb'
io = NWBHDF5IO(r"C:\Users\Saksham\Documents\NWB\roiextractors\testdatasets\GiocomoData\4139265.5\10_02_2019\TwoTOwer_foraging\TwoTower_foraging_003_006_small_imaging - Copy (2).nwb", mode='r', load_namespaces=True)
nwb = io.read()
a=nwb2widget(nwb)
print(type(a))
# Out:
# <class 'ipywidgets.widgets.widget_box.VBox'>

# %%
display(a)
